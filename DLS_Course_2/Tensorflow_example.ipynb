# %%
import numpy as np
import tensorflow as tf

# %%
# 변수 정의, 0으로 초기화
# w는 최적화하고자 하는 parameter
w = tf.Variable(0, dtype=tf.float32)
# 최적화 알고리즘 정의
# learning_rate = 0,1
optimizer = tf.keras.optimizers.Adam(0.1)

def train_step():
  # forward 단계에서 cost를 계산할 때 작업 순서를 기록
  # 테이프를 backward로 하면 역순으로 조작 순서를 다시 확인할 수 있음
  # 역전파 및 기울기를 계산하는 단계 포함
  with tf.GradientTape() as tape:
    cost = w ** 2 - 10 * w + 25

  trainable_variables = [w]
  grads = tape.gradient(cost, trainable_variables)
  optimizer.apply_gradients(zip(grads, trainable_variables))

print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>

# %%
train_step()
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.09999931>

# %%
for i in range(1000):
  train_step()
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.000001>

# %%
# Another approach

# %%
w = tf.Variable(0, dtype=tf.float32)
x = np.array([1.0, -10.0, 25.0], dtype=np.float32)
optimizer = tf.keras.optimizers.Adam(0.1)

def training(x, w, optimizer):
  def cost_fn():
    # 이 공식이 tensorflow가 연산 그래프를 구성할 수 있게 함
    return x[0] * w ** 2 + x[1] * w + x[2]
  for i in range(1000):
    optimizer.minimize(cost_fn, [w])
  return w

w = training(x, w, optimizer)
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.000001>
